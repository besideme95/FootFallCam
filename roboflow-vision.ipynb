# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="E0QwqXet8HhICIBjJ1xQ")
project = rf.workspace("footfallcam-xahbc").project("image-fu9jl")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.95, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to image-1 in yolov8:: 100%|██████████| 1955/1955 [00:00<00:00, 2392.46it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 patience=5
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/runs/detect/train/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print('\n')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
